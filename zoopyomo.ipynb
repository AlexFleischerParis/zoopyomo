# %%
# !pip install pyomo
# Out:
# Collecting pyomo
#   Downloading Pyomo-6.4.2-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (10.5 MB)
#      |████████████████████████████████| 10.5 MB 18.9 MB/s eta 0:00:01
# Collecting ply
#   Downloading ply-3.11-py2.py3-none-any.whl (49 kB)
#      |████████████████████████████████| 49 kB 11.7 MB/s eta 0:00:01
# Installing collected packages: ply, pyomo
# Successfully installed ply-3.11 pyomo-6.4.2

# %%
import pyomo.environ as pyo
from pyomo.opt import SolverFactory

opt = pyo.SolverFactory("cplex_direct")

model = pyo.ConcreteModel()

model.nbBus = pyo.Var([40,30], domain=pyo.PositiveIntegers)

model.OBJ = pyo.Objective(expr = 500*model.nbBus[40] + 400*model.nbBus[30])

model.Constraint1 = pyo.Constraint(expr = 40*model.nbBus[40] + 30*model.nbBus[30] >= 300)

opt.solve(model)

print("nbBus40 =",model.nbBus[40].value)
print("nbBus30 =",model.nbBus[30].value)
# Out:
# nbBus40= 6.0
# nbBus30= 2.0
